# %% [markdown]
# <a href="https://colab.research.google.com/github/Manvi190502/AgenticAI/blob/main/agentic_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install langchain-google-genai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.3/53.3 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 713.3/713.3 kB 17.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 490.2/490.2 kB 28.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 234.9/234.9 kB 16.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.43.0
#     Uninstalling google-auth-2.43.0:
#       Successfully uninstalled google-auth-2.43.0
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.2.1
#     Uninstalling langchain-core-1.2.1:
#       Successfully uninstalled langchain-core-1.2.1
#   Attempting uninstall: google-genai
#     Found existing installation: google-genai 1.55.0
#     Uninstalling google-genai-1.55.0:
#       Successfully uninstalled google-genai-1.55.0
# ...

# %%
GOOGLE_API_KEY="AIzaSyAAvx0pfQhp7EgmBETL_YTzQGdJudj2LrQ"

# %%
import google.generativeai as genai
genai.configure(api_key=GOOGLE_API_KEY)
model=genai.GenerativeModel("gemini-2.5-flash")
prompt="Explain prompt engineering in simple terms."
response=model.generate_content(prompt)
print(response.text)
# Out:
# Imagine you have a super-smart, super-fast assistant (that's the AI).
#
# **Prompt engineering is like learning how to talk to that assistant in just the right way to get exactly what you want, every single time.**
#
# Here's a breakdown:
#
# 1.  **The "Prompt":** This is your instruction, question, or request to the AI. It's what you type into the chatbox.
#     *   *Simple prompt:* "Write a poem about dogs."
#
# 2.  **The "Engineering":** This is the skill and art of designing that prompt. It means carefully choosing your words, adding context, specifying details, and even giving examples to guide the AI. You're *engineering* the perfect set of instructions.
#
# **Why is it important?**
#
# Because AI, despite being smart, can also be very literal or general.
#
# *   **Bad Prompt:** "Write a story."
#     *   *AI might give you:* A very generic, short story about anything. Not very useful.
#
# ...

# %%
import os
from google.colab import userdata

os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")

# %%
assert os.environ["GOOGLE_API_KEY"] is not None
print("API key loaded successfully")
# Out:
# API key loaded successfully

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
    # other params...
)
response = llm.invoke("Explain prompt engineering in simple terms.")
print(response)
# Out:
# content='Imagine you have a super-smart, incredibly knowledgeable assistant (that\'s the AI).\n\n**1. What is a "Prompt"?**\nA "prompt" is simply the **instruction or question you give to that AI assistant.**\n*   "Write a poem about cats."\n*   "Summarize this article."\n*   "Explain quantum physics in simple terms."\n\n**2. What is "Engineering" in this context?**\nIt\'s not about building bridges! Here, "engineering" means **designing, refining, and optimizing something to get the best possible outcome.**\n\n---\n\n**So, Prompt Engineering is:**\n\nIt\'s the **art and science of crafting the best possible instructions (prompts) for an AI to get the best possible results.**\n\nThink of it like this:\n\n*   **Simple Prompt:** "Make food." (The AI might give you a very generic recipe, or ask for more details.)\n*   **Engineered Prompt:** "As a Michelin-star chef, create a recipe for a gourmet, vegetarian pasta dish that can be prepared in under 30 minutes. The recipe should serve two
# ...
